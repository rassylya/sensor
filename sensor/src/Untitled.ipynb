# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
ls
# Out:
# accel_check.py     hall_calibrate.cpp        move_up_down.py
# accel_ml.py*       HexFT.cpp                 publisher_accelerometer.py
# accel_pub.py       HexFT.h                   recordAudio.py
# checkaudio.py      home_pos.py               sensors.csv
# contact_slide.cpp  hri.cpp                   texture_recognition/
# force_control.cpp  listener_wittenstein.cpp  trash_codes/
# force_pub.cpp      main.cpp                  Untitled.ipynb
# get_force.cpp      ml_data.cpp*

# %%
df = pd.read_csv('sensors.csv', header = None)

# %%
y1 = df[1]
y2 = df[2]

# %%
x1 = list(range(len(y1)))
x2 = list(range(len(y2)))

# %%
plt.plot(x1,y1)

# %%
plt.plot(x2,y2)

# %%
plt.plot(x2[2050:2100],y2[2050:2100])

# %%
l = y2[:800]
print(max(l)) 540
print(min(l))
print(max(l)-min(l))
# Out:
# -0.1063232421875
# -0.12060546875
# 0.0142822265625

# %%
i = 0
cur = y2[0]
prev = y2[0]
dif = 0
while i<1000:
    if dif >= 0.0045:
        break
    cur = y2[i]
    dif = abs(cur) - abs(prev)
#     print(dif)
    i += 1
    prev = cur
print(2070-540)
# Out:
# 1530

# %%
print(y2[364])
# Out:
# -0.12042236328125

# %%
df
# Out:
#                         0         1         2    3         4
# 0     1684678168832943439 -0.025513 -0.113831 -1.0 -0.999969
# 1     1684678168833291530 -0.026001 -0.113556 -1.0 -0.999969
# 2     1684678168834298849 -0.026367 -0.113403 -1.0 -0.999969
# 3     1684678168835264921 -0.026062 -0.113922 -1.0 -0.999969
# 4     1684678168836265563 -0.026093 -0.114258 -1.0 -0.999969
# ...                   ...       ...       ...  ...       ...
# 6764  1684678177689440011 -0.022522 -0.107422 -1.0 -0.999969
# 6765  1684678177690322399 -0.022675 -0.107697 -1.0 -0.999969
# 6766  1684678177691432476 -0.020142 -0.106445 -1.0 -0.999969
# 6767  1684678177692324876 -0.018005 -0.107849 -1.0 -0.999969
# 6768  1684678178296410560 -0.018677 -0.109375 -1.0 -0.999969
#
# [6769 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the graph data

# Find the period of the graph
period = np.diff(y2[:, 0])[-1]

# Plot the graph
plt.plot(y2[:, 0], y2[:, 1])
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Graph Period")
plt.show()

print("The period of the graph is:", period)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 7
#       2 import numpy as np
#       4 # Load the graph data
#       5
#       6 # Find the period of the graph
# ----> 7 period = np.diff(y2[:, 0])[-1]
#       9 # Plot the graph
#      10 plt.plot(y2[:, 0], y2[:, 1])
#
# File ~/miniconda3/envs/py3.10-env/lib/python3.10/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     key = np.asarray(key, dtype=bool)
#    1005     return self._get_values(key)
# -> 1007 return self._get_with(key)
#
# File ~/miniconda3/envs/py3.10-env/lib/python3.10/site-packages/pandas/core/series.py:1022, in Series._get_with(self, key)
#    1017     raise TypeError(
#    1018         "Indexing a Series with DataFrame is not "
#    1019         "supported, use the appropriate DataFrame column"
#    1020     )
#    1021 elif isinstance(key, tuple):
# ...
